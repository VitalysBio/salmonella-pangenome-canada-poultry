# %% [markdown]
# ## Genome quality control and selection
# All candidate genomes were evaluated using a quality control procedure based on assembly metrics. For each assembly, a composite quality score (`quality_score`) was calculated by integrating:
# - Assembly continuity (N50)
# - Sequencing depth (coverage)
# - Assembly fragmentation (number of contigs ≥200 bp)
#
# Genomes were then grouped by geographic region. Within each region, the five assemblies with the highest quality scores were selected. This stratified sampling strategy was used to:
# - Maximize the overall quality of the final dataset
# - Preserve regional representativeness
# - Avoid bias caused by over-representation of regions with higher numbers of available isolates
#
# Only the top-ranked genomes per region, together with their associated metadata and quality metrics, were retained for downstream analyses.

# %%
import pandas as pd
import re
from pathlib import Path

# %%
path_df = Path('/salmonella-pangenome-SP/data/Metadata/meta_sp_total.txt')
assert path_df.exists(), f'no se encuentra el fichero'

# %%
df = pd.read_csv(path_df, sep='\t', dtype=str, engine='python')
print(df.head(3))
print('original columns', list(df.columns))
print('Shape: ', df.shape)
# Out:
#      Uberstrain        Name  \
# 0  SAL_BA6133AA   OSF031120
# 1  SAL_DA9157AA  EC20100134
# 2  SAL_DA9158AA  EC20100130
#
#   Data Source(Accession No.;Sequencing Platform;Sequencing Library;Insert Size;Experiment;Bases;Average Length;Status)  \
# 0  SRR1995504;ILLUMINA;Paired;500;SRX1008539;2371...
# 1  SRR1183994;LS454;Single;;SRX481517;;;NEW,GCF_0...
# 2  SRR1183993;LS454;Single;;SRX481516;;;NEW,GCF_0...
#
#         Barcode Source Niche Source Type Source Details Collection Year  \
# 0  SAL_BA6133AA      Poultry     Poultry        chicken            2014
# 1  SAL_DA9157AA      Poultry     Poultry        chicken            2009
# 2  SAL_DA9158AA      Poultry     Poultry        chicken            2009
#
#   Collection Month Collection Day  ... Release Date     Status Coverage  \
# 0                4            NaN  ...   2015-04-24  Assembled       51
# 1              NaN            NaN  ...   2015-03-05  Assembled        1
# 2              NaN            NaN  ...   2015-03-05  Assembled        1
#
#        N50   Length                     Species Contig Number(>=200 bp)  \
# 0    89072  4733951  Salmonella enterica;100.0%                     130
# 1  4766248  4766248                         NaN                       1
# 2  4773474  4773474                         NaN                       1
#
#   Low Quality Bases Version Assembly Barcode
# 0             19814     2.2  SAL_EA5295AA_AS
# 1                 8     NaN  SAL_KA3434AA_AS
# 2                15     NaN  SAL_KA3433AA_AS
#
# [3 rows x 41 columns]
# original columns ['Uberstrain', 'Name', 'Data Source(Accession No.;Sequencing Platform;Sequencing Library;Insert Size;Experiment;Bases;Average Length;Status)', 'Barcode', 'Source Niche', 'Source Type', 'Source Details', 'Collection Year', 'Collection Month', 'Collection Day', 'Collection Time', 'Continent', 'Country', 'Region', 'District', 'City', 'Post Code', 'Latitude', 'Longitude', 'Serovar', 'Subspecies', 'Disease', 'Antigenic Formulas', 'Lab Contact', 'Phage Type', 'Comment', 'Bio Project ID', 'Project ID', 'Sample ID', 'Secondary Sample ID', 'Date Entered', 'Release Date', 'Status', 'Coverage', 'N50', 'Length', 'Species', 'Contig Number(>=200 bp)', 'Low Quality Bases', 'Version', 'Assembly Barcode']
# Shape:  (175, 41)

# %% [markdown]
# ## Normalize columns downloaded from Enterobase

# %%
def normalize_col(col: str) -> str:
    c = str(col).strip()    
    c = re.sub(r"[^A-Za-z0-9]+", "_", c)
    c = c.replace("_200_bp", "")
    c = re.sub(r"_+", "_", c)                 
    return c.strip("_").lower()

df.columns = [normalize_col(c) for c in df.columns]
print("Normalize columns:", list(df.columns))
# Out:
# Normalize columns: ['uberstrain', 'name', 'data_source_accession_no_sequencing_platform_sequencing_library_insert_size_experiment_bases_average_length_status', 'barcode', 'source_niche', 'source_type', 'source_details', 'collection_year', 'collection_month', 'collection_day', 'collection_time', 'continent', 'country', 'region', 'district', 'city', 'post_code', 'latitude', 'longitude', 'serovar', 'subspecies', 'disease', 'antigenic_formulas', 'lab_contact', 'phage_type', 'comment', 'bio_project_id', 'project_id', 'sample_id', 'secondary_sample_id', 'date_entered', 'release_date', 'status', 'coverage', 'n50', 'length', 'species', 'contig_number', 'low_quality_bases', 'version', 'assembly_barcode']

# %% [markdown]
# ## Identify and split composite columns

# %%
column_c = [c for c in df.columns if 'data_source_' in c]
expanded = df[column_c[0]].str.split(';', n=7, expand=True)
expanded.columns = ['accession_no',
                    'sequencing_platform',
                    'sequencing_library',
                    'insert_size',
                    'experiment',
                    'bases',
                    'average_length',
                    'status'
                   ]  
for col in expanded.columns: 
    df[col] = expanded[col].str.strip() 

# Remove the original column

df = df.drop(columns=[column_c[0]])
print(df.head(2))
# Out:
#      uberstrain        name       barcode source_niche source_type  \
# 0  SAL_BA6133AA   OSF031120  SAL_BA6133AA      Poultry     Poultry
# 1  SAL_DA9157AA  EC20100134  SAL_DA9157AA      Poultry     Poultry
#
#   source_details collection_year collection_month collection_day  \
# 0        chicken            2014                4            NaN
# 1        chicken            2009              NaN            NaN
#
#   collection_time  ... low_quality_bases version assembly_barcode  \
# 0             NaN  ...             19814     2.2  SAL_EA5295AA_AS
# 1             NaN  ...                 8     NaN  SAL_KA3434AA_AS
#
#   accession_no sequencing_platform sequencing_library insert_size  experiment  \
# 0   SRR1995504            ILLUMINA             Paired         500  SRX1008539
# 1   SRR1183994               LS454             Single               SRX481517
#
#        bases average_length
# 0  237155400            225
# 1
#
# [2 rows x 47 columns]

# %%
# Convert the variables of interest to numeric values
for col in ['n50', 'coverage', 'contig_number']:
    df[col]= pd.to_numeric(df[col], errors='coerce')

# %%
# Creating quality metrics
df['quality_score']= df['n50'].fillna(0)/500000 + df['coverage'].fillna(0)/50 + (200 - df['contig_number'].fillna(200))/20
# It's divided so that each metric has a similar weight. If we don't know how many contigs that entry has, 
# we penalize it heavily, assuming a gigantic value, so that sample will come out with a very low score and will almost never be the best.

print(df.head(5))

# Working just with poultry sources
df_trabajo = df[df['source_niche']=='Poultry']

print(df_trabajo.head(5))
# Out:
#      uberstrain        name       barcode source_niche source_type  \
# 0  SAL_BA6133AA   OSF031120  SAL_BA6133AA      Poultry     Poultry
# 1  SAL_DA9157AA  EC20100134  SAL_DA9157AA      Poultry     Poultry
# 2  SAL_DA9158AA  EC20100130  SAL_DA9158AA      Poultry     Poultry
# 3  SAL_DA9159AA  EC20090884  SAL_DA9159AA      Poultry     Poultry
# 4  SAL_DA9160AA  EC20090531  SAL_DA9160AA      Poultry     Poultry
#
#   source_details collection_year collection_month collection_day  \
# 0        chicken            2014                4            NaN
# 1        chicken            2009              NaN            NaN
# 2        chicken            2009              NaN            NaN
# 3        chicken            2009              NaN            NaN
# 4        chicken            2009              NaN            NaN
#
#   collection_time  ... version assembly_barcode accession_no  \
# 0             NaN  ...     2.2  SAL_EA5295AA_AS   SRR1995504
# 1             NaN  ...     NaN  SAL_KA3434AA_AS   SRR1183994
# 2             NaN  ...     NaN  SAL_KA3433AA_AS   SRR1183993
# 3             NaN  ...     NaN  SAL_KA3474AA_AS   SRR1183992
# 4             NaN  ...     NaN  SAL_KA3473AA_AS   SRR1183991
#
#   sequencing_platform sequencing_library insert_size  experiment      bases  \
# 0            ILLUMINA             Paired         500  SRX1008539  237155400
# 1               LS454             Single               SRX481517
# 2               LS454             Single               SRX481516
# 3               LS454             Single               SRX481515
# 4               LS454             Single               SRX481514
#
#   average_length quality_score
# 0            225      4.698144
# 1                    19.502496
# 2                    19.516948
# 3                    19.490898
# 4                    19.439780
#
# [5 rows x 48 columns]
#      uberstrain        name       barcode source_niche source_type  \
# 0  SAL_BA6133AA   OSF031120  SAL_BA6133AA      Poultry     Poultry
# 1  SAL_DA9157AA  EC20100134  SAL_DA9157AA      Poultry     Poultry
# 2  SAL_DA9158AA  EC20100130  SAL_DA9158AA      Poultry     Poultry
# 3  SAL_DA9159AA  EC20090884  SAL_DA9159AA      Poultry     Poultry
# 4  SAL_DA9160AA  EC20090531  SAL_DA9160AA      Poultry     Poultry
#
#   source_details collection_year collection_month collection_day  \
# 0        chicken            2014                4            NaN
# 1        chicken            2009              NaN            NaN
# 2        chicken            2009              NaN            NaN
# 3        chicken            2009              NaN            NaN
# 4        chicken            2009              NaN            NaN
#
#   collection_time  ... version assembly_barcode accession_no  \
# 0             NaN  ...     2.2  SAL_EA5295AA_AS   SRR1995504
# 1             NaN  ...     NaN  SAL_KA3434AA_AS   SRR1183994
# 2             NaN  ...     NaN  SAL_KA3433AA_AS   SRR1183993
# 3             NaN  ...     NaN  SAL_KA3474AA_AS   SRR1183992
# 4             NaN  ...     NaN  SAL_KA3473AA_AS   SRR1183991
#
#   sequencing_platform sequencing_library insert_size  experiment      bases  \
# 0            ILLUMINA             Paired         500  SRX1008539  237155400
# 1               LS454             Single               SRX481517
# 2               LS454             Single               SRX481516
# 3               LS454             Single               SRX481515
# 4               LS454             Single               SRX481514
#
#   average_length quality_score
# 0            225      4.698144
# 1                    19.502496
# 2                    19.516948
# 3                    19.490898
# 4                    19.439780
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Working dataframe

# %%
# Creating metadata with the main data of the genomes to be worked on
df_final = (
    df_trabajo
    .groupby('region', group_keys=False)
    .apply(lambda x: x.nlargest(5, 'quality_score'))
    .assign(
        # 1. FASTA name per genome
        sample_fasta=lambda d: (
            d['region'].astype(str) + "_" +
            d['name'].astype(str) + "_" +
            d['accession_no'].astype(str)
        ),

        # 2. Sequence type
        sequence_type=lambda d: np.where(
            d['serovar'].str.lower().str.contains("enteritidis"),
            "ST11",
            np.where(
                d['serovar'].str.lower().str.contains("heidelberg"),
                "ST15",
                np.nan
            )
        ),

        # 3. FASTA assembly
        fasta_source=lambda d: np.where(
            d['accession_no'].str.startswith("GCF"),
            "NCBI_RefSeq",
            np.where(
                d['accession_no'].str.startswith("SRR"),
                "EnteroBase_assembly",
                np.nan
            )
        )
    )
    [[
        "region", "name", "accession_no", "assembly_barcode",
        "serovar", "sequence_type",
        "source_niche", "source_details",
        "collection_year", "country", "lab_contact",
        "n50", "contig_number", "coverage", "quality_score",
        "sample_fasta", "fasta_source"
    ]]
)

df_final['sample_fasta'] = df_final['sample_fasta'].str.replace(" ", "_", regex=False)

df_final[df_final['sample_fasta'].str.contains(" ")]

print(df_final)
# Out:
#               region        name   accession_no assembly_barcode      serovar  \
# 11           Alberta  EC20090641     SRR1183981  SAL_KA3404AA_AS  Enteritidis
# 35           Alberta  EC20111515  GCF_000624315  SAL_PA7468AA_AS  Enteritidis
# 32           Alberta  EC20120677  GCF_000625755  SAL_PA7476AA_AS  Enteritidis
# 34           Alberta  EC20111514  GCF_000624295  SAL_PA7505AA_AS  Enteritidis
# 10           Alberta  EC20090698     SRR1183982  SAL_KA3468AA_AS  Enteritidis
# 31  British Columbia  EC20120765  GCF_000624995  SAL_PA7576AA_AS  Enteritidis
# 30  British Columbia  EC20111554  GCF_000624335  SAL_PA7506AA_AS  Enteritidis
# 33  British Columbia  EC20111510  GCF_000626555  SAL_PA7485AA_AS  Enteritidis
# 17  British Columbia  EC20120686  GCF_000625555  SAL_PA7535AA_AS  Enteritidis
# 37  British Columbia  EC20120685  GCF_000625535  SAL_PA7470AA_AS  Enteritidis
# 46     New Brunswick   N13-02934     SRR5241846  SAL_QA6543AA_AS   Heidelberg
# 68     New Brunswick   N13-02944     SRR5241820  SAL_QA5373AA_AS   Heidelberg
# 42     New Brunswick   N13-02946     SRR5241852  SAL_QA6290AA_AS   Heidelberg
# 19       Nova Scotia  EC20120590  GCF_000625495  SAL_PA7597AA_AS  Enteritidis
# 29           Ontario  EC20120916  GCF_000624155  SAL_KA3476AA_AS  Enteritidis
# 5            Ontario  EC20090332     SRR1183990  SAL_KA3477AA_AS  Enteritidis
# 7            Ontario  EC20090193     SRR1183988  SAL_KA3478AA_AS  Enteritidis
# 2            Ontario  EC20100130     SRR1183993  SAL_KA3433AA_AS  Enteritidis
# 6            Ontario  EC20090135     SRR1183989  SAL_KA3479AA_AS  Enteritidis
# 90            Quebec   N13-01312     SRR5239201  SAL_QA5780AA_AS   Heidelberg
# 82            Quebec   N13-01311     SRR5239213  SAL_QA6400AA_AS   Heidelberg
# 57            Quebec   N13-01348     SRR5241832  SAL_QA5385AA_AS   Heidelberg
# 53            Quebec   N13-01330     SRR5241836  SAL_QA5389AA_AS   Heidelberg
# 51            Quebec   N13-01323     SRR5241839  SAL_QA5815AA_AS   Heidelberg
#
#    sequence_type source_niche                  source_details collection_year  \
# 11          ST11      Poultry       chicken-abbatoir-Sporadic            2008
# 35          ST11      Poultry                  ANIMAL-chicken            2010
# 32          ST11      Poultry                  ANIMAL-chicken            2011
# 34          ST11      Poultry                  ANIMAL-chicken            2010
# 10          ST11      Poultry       chicken-abbatoir-Sporadic            2008
# 31          ST11      Poultry                  ANIMAL-chicken            2011
# 30          ST11      Poultry                  ANIMAL-chicken            2010
# 33          ST11      Poultry                  ANIMAL-chicken            2010
# 17          ST11      Poultry                  ANIMAL-chicken            2011
# 37          ST11      Poultry                  ANIMAL-chicken            2011
# 46          ST15      Poultry  Animal cecal content (chicken)            2011
# 68          ST15      Poultry  Animal cecal content (chicken)            2012
# 42          ST15      Poultry  Animal cecal content (chicken)            2012
# 19          ST11      Poultry                  ANIMAL-chicken            2011
# 29          ST11      Poultry                  ANIMAL-chicken            2012
# 5           ST11      Poultry                         chicken            2008
# 7           ST11      Poultry                         chicken            2008
# 2           ST11      Poultry                         chicken            2009
# 6           ST11      Poultry                         chicken            2008
# 90          ST15      Poultry  Animal cecal content (chicken)            2012
# 82          ST15      Poultry  Animal cecal content (chicken)            2012
# 57          ST15      Poultry  Animal cecal content (chicken)            2012
# 53          ST15      Poultry  Animal cecal content (chicken)            2012
# 51          ST15      Poultry  Animal cecal content (chicken)            2012
#
#    country                                        lab_contact      n50  \
# 11  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4712309
# 35  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4685847
# 32  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4685846
# 34  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4685845
# 10  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4680996
# 31  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4685984
# 30  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4685846
# 33  Canada                        Public Health Agency Canada  4685842
# 17  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4685835
# 37  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4685833
# 46  Canada                     Public Health Agency of Canada   693848
# 68  Canada                     Public Health Agency of Canada   694160
# 42  Canada                     Public Health Agency of Canada   412159
# 19  Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4685840
# 29  Canada                        Public Health Agency Canada  4807994
# 5   Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4785193
# 7   Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4774402
# 2   Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4773474
# 6   Canada  Laboratory for Foodborne Zoonoses, Public Heal...  4771194
# 90  Canada                     Public Health Agency of Canada   725299
# 82  Canada                     Public Health Agency of Canada   725299
# 57  Canada                     Public Health Agency of Canada   740519
# 53  Canada                     Public Health Agency of Canada   725307
# 51  Canada                     Public Health Agency of Canada   439677
#
#     contig_number  coverage  quality_score  \
# 11              1       1.0      19.394618
# 35              1       1.0      19.341694
# 32              1       1.0      19.341692
# 34              1       1.0      19.341690
# 10              1       1.0      19.331992
# 31              1       1.0      19.341968
# 30              1       1.0      19.341692
# 33              1       1.0      19.341684
# 17              1       1.0      19.341670
# 37              1       1.0      19.341666
# 46             43     215.0      13.537696
# 68             46     164.0      12.368320
# 42             48     129.0      11.004318
# 19              1       1.0      19.341680
# 29              1       1.0      19.585988
# 5               1       1.0      19.540386
# 7               1       1.0      19.518804
# 2               1       1.0      19.516948
# 6               1       1.0      19.512388
# 90             39     192.0      13.340598
# 82             36     178.0      13.210598
# 57             34     155.0      12.881038
# 53             39     164.0      12.780614
# 51             37     176.0      12.549354
#
#                                  sample_fasta         fasta_source
# 11              Alberta_EC20090641_SRR1183981  EnteroBase_assembly
# 35           Alberta_EC20111515_GCF_000624315          NCBI_RefSeq
# 32           Alberta_EC20120677_GCF_000625755          NCBI_RefSeq
# 34           Alberta_EC20111514_GCF_000624295          NCBI_RefSeq
# 10              Alberta_EC20090698_SRR1183982  EnteroBase_assembly
# 31  British_Columbia_EC20120765_GCF_000624995          NCBI_RefSeq
# 30  British_Columbia_EC20111554_GCF_000624335          NCBI_RefSeq
# 33  British_Columbia_EC20111510_GCF_000626555          NCBI_RefSeq
# 17  British_Columbia_EC20120686_GCF_000625555          NCBI_RefSeq
# 37  British_Columbia_EC20120685_GCF_000625535          NCBI_RefSeq
# 46         New_Brunswick_N13-02934_SRR5241846  EnteroBase_assembly
# 68         New_Brunswick_N13-02944_SRR5241820  EnteroBase_assembly
# 42         New_Brunswick_N13-02946_SRR5241852  EnteroBase_assembly
# 19       Nova_Scotia_EC20120590_GCF_000625495          NCBI_RefSeq
# 29           Ontario_EC20120916_GCF_000624155          NCBI_RefSeq
# 5               Ontario_EC20090332_SRR1183990  EnteroBase_assembly
# 7               Ontario_EC20090193_SRR1183988  EnteroBase_assembly
# 2               Ontario_EC20100130_SRR1183993  EnteroBase_assembly
# 6               Ontario_EC20090135_SRR1183989  EnteroBase_assembly
# 90                Quebec_N13-01312_SRR5239201  EnteroBase_assembly
# 82                Quebec_N13-01311_SRR5239213  EnteroBase_assembly
# 57                Quebec_N13-01348_SRR5241832  EnteroBase_assembly
# 53                Quebec_N13-01330_SRR5241836  EnteroBase_assembly
# 51                Quebec_N13-01323_SRR5241839  EnteroBase_assembly
# /tmp/ipykernel_5250/1706637055.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.nlargest(5, 'quality_score'))

# %%
out_path = "/salmonella-pangenome-SP/data/Metadata/metadata_samples.tsv"

df_final.to_csv(
    out_path,
    sep="\t",
    index=False
)

# %%
genomes_df = df_final[["sample_fasta", "accession_no", "fasta_source"]]

out_path = "/salmonella-pangenome-SP/data/Metadata/genomes_manifest.tsv"
genomes_df.to_csv(
    out_path,
    sep="\t",
    index=False
)
